# %%
import numpy as np
import pandas as pd
from datetime import datetime
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

sns.set()
import warnings
warnings.filterwarnings('ignore')




from sklearn.preprocessing import StandardScaler

from sklearn.ensemble import RandomForestClassifier, RandomForestRegressor
from sklearn.linear_model import LogisticRegression, LogisticRegressionCV
from sklearn.linear_model import LinearRegression, LassoCV, RidgeCV
from sklearn.linear_model import PassiveAggressiveRegressor
from sklearn.ensemble import BaggingRegressor
from sklearn.svm import SVR

from sklearn.model_selection import cross_val_score
from sklearn.model_selection import train_test_split

# Regression metrics
from sklearn.metrics import explained_variance_score, mean_squared_error
from sklearn.metrics import mean_absolute_error, r2_score

from sklearn import metrics
from sklearn.metrics import accuracy_score
from sklearn.metrics import classification_report

# %%
class bikeSales:
    
    
    file = 'clean_sport2.csv'
    df = None
    scaled_df = None
    model = {'Mode': None,
             'Features': [],
             'Score': 0}
    
    
    
    
    def read_data(self):
        df = pd.read_csv(self.file,
                         parse_dates=['First_Seen','Last_Seen','Last_Modified'], 
                         infer_datetime_format=True)
        self.df = df
        return


    def add_dummy_variables(self, categorical_features=None):
        
        if (categorical_features == None):
            categorical_features = self.df.select_dtypes(exclude='number').columns
            
        additional = pd.get_dummies(self.df[categorical_features])
        self.df[additional.columns] = additional
        
        self.df.drop(categorical_features, axis=1, inplace=True)
        return

    def feature_plot(model,X,top=10):

        feats_imp = pd.DataFrame(model.feature_importances_, index=X.columns, columns=['FeatureImportance'])
        feats_imp = feats_imp.sort_values('FeatureImportance', ascending=False)[:top]

        feats_imp.plot(kind='barh', figsize=(12,6), legend=False)
        plt.title('Feature Importance from XgBoost Classifier')
        sns.despine(left=True, bottom=True)
        plt.gca().invert_yaxis()
        return

    def plot_accuracy_predictions(self, y_test, pred):
        fig, ax = plt.subplots(figsize=(12,10))
        ax.scatter(y_test,pred)
        ax.plot([y_test.min(), y_test.max()], [y_test.min(), y_test.max()], 'r--', lw=0.8)
        ax.set_xlabel('Measured')
        ax.set_ylabel('Predicted')
        ax.set_title('Accuracy of Predictions')
        return
    
    
    def scale_data(self, target='Price'):
        local_df = self.df.select_dtypes(include='number')

        features = list(set(local_df.columns) - set([target]))

        sc = StandardScaler()
        sc.fit(self.df[features])
        s = sc.transform(self.df[features])
        self.scaled_df = pd.DataFrame(s,columns=features)

        return
    
    
    def adjusted_r2(self, r2, n, k):
        return 1 - (1-r2)*((n-1)/(n-k-1)) 


    def find_best_model(self, features, y, scaled=False):
        
        self.model['Features'] = features
        X = self.df[features]
        y = self.df['Price']
        
        if scaled == True:
            X = self.scaled_df[features]
            

        X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=1, test_size=0.3)

        best_score = 0
        models = []

        models.append(("LassoCV",LassoCV(cv=5)))
        models.append(("LinearRegression",LinearRegression()))
        models.append(("PassiveAggressiveRegressor",PassiveAggressiveRegressor()))
        models.append(("RidgeCV",RidgeCV(cv=5)))
        models.append(("Bagging",BaggingRegressor()))
        models.append(("SVR",SVR()))

        n, k = X_train.shape

        for name, model in models:
            score = cross_val_score(model, X_train, y_train,  cv=5)

            result = self.adjusted_r2(score,n,k)
                    
            if (result.mean() > best_score):
                best_score = result.mean()
                self.model['Model'] = model
                self.model['Score'] = result.mean()
                
        return

    def feature_selection(self, features):
        ## Use Forward Feature Selection to pick a good model
        target = 'Price'
        #features = list(set(self.df.columns) - set([target]))
        X = self.df[features]
        y = self.df[target]

        X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=1, test_size=0.3)

        # start with no predictors
        included = []
        # keep track of model and parameters
        best = {'feature': '', 'r2': 0, 'a_r2': 0}
        # create a model object to hold the modelling parameters
        model = self.model['Model'] 
        # get the number of cases in the test data
        n = X_test.shape[0]

        while True:
            changed = False

            # list the features to be evaluated
            excluded = list(set(features) - set(included))

            # for each remaining feature to be evaluated
            for new_column in excluded:

                # fit the model with the Training data
                fit = model.fit(X_train[included + [new_column]], y_train) # fit a model; consider which predictors should be included
                # calculate the score (R^2 for Regression)
                r2 = model.score(X_test[included + [new_column]], y_test) # calculate the score
                # number of predictors in this model
                k = len(included + [new_column]) + 1
                # calculate the adjusted R^2
                adjusted_r = self.adjusted_r2(r2,n,k) 


                # if model improves
                if adjusted_r > best['a_r2']:
                    # record new parameters
                    best = {'feature': new_column, 'r2': r2, 'a_r2': adjusted_r}
                    # flag that found a better model
                    changed = True

            # if found a better model after testing all remaining features
            if changed:
                # update control details
                included.append(best['feature'])
                excluded = list(set(excluded) - set(best['feature']))
                print(f'Added feature: {best["feature"]} with adjusted R^2 = {best["a_r2"]:.3}')
            else:
                # terminate if no better model
                break

        print('')
        print('Resulting features:')
        print(', '.join(included))
        self.model['Features'] = included
        self.model['Score'] = best['a_r2']
        
        return
        
        

    def fit(self, X, y):
        self.model['Model'].fit(X, y)
        return
        
        
    def predict(self, X):
        return self.model['Model'].predict(X)
    
    def deal_type(self):
#         if ('Predicted_Price' not in list(self.df.columns)):
#             raise 
        
        self.df['Price_ratio'] = self.df['Price'] / self.df['Predicted_Price']

        self.df['Deal_type'] = 'Dont Bother'
        self.df['Deal_type'][self.df['Price_ratio'] < 0.9] = 'Negotiate'
        self.df['Deal_type'][self.df['Price_ratio'] < 0.8] = 'Good Deal'
        self.df['Deal_type'][self.df['Price_ratio'] < 0.75] = 'Great Deal'        
        self.df['Deal_type'][self.df['Price_ratio'] < 0.5] = 'Its a steal'
        
#         self.df['Deal_type'][self.df['Price_ratio'] > 1.1] = 'Negotiate'
#         self.df['Deal_type'][self.df['Price_ratio'] > 1.2] = 'Good Deal'
#         self.df['Deal_type'][self.df['Price_ratio'] > 1.5] = 'Great Deal'        
#         self.df['Deal_type'][self.df['Price_ratio'] > 2.0] = 'Its a steal'
        
        return
        
    
    def plot_deals(self,x,y,hue=None,title='',figsize=(12,10)):
        ax = plt.figure(figsize=figsize)
        sns.scatterplot(x=x,y=y,hue=hue,data=self.df);
        plt.title(title,fontsize=14)
        plt.legend(bbox_to_anchor=(1.05, 1), loc=2, borderaxespad=0.)
        #plt.ylim(0,40000)

# %%
sport = bikeSales()

# %%
sport.read_data()

# %%
sport.df.shape
# Out:
# (2558, 62)

# %%
sport.add_dummy_variables()

# %%
sport.df.shape
# Out:
# (2558, 643)

# %%
# sport.scale_data(target='Price')
# sport.scaled_df.describe()

# %%
niave_feature = ['Kilometers','Age']
sport.find_best_model(niave_feature, sport.df['Price'])
print ('Model: ',sport.model['Model'])
print ('Score: ',sport.model['Score'])
# Out:
# Model:  RidgeCV(alphas=array([ 0.1,  1. , 10. ]), cv=5, fit_intercept=True,
#     gcv_mode=None, normalize=False, scoring=None, store_cv_values=False)
# Score:  0.11380941145674502

# %%
sport.fit(sport.df[niave_feature],sport.df['Price'])

predictions = sport.predict(sport.df[niave_feature])

# %%
sport.df['Predicted_Price'] = predictions
sport.df[['Price','Predicted_Price']].head()
# Out:
#     Price  Predicted_Price
# 0   600.0       559.599043
# 1  1500.0      5601.015318
# 2  1700.0      9292.768836
# 3  1900.0      4202.627219
# 4  1990.0      5751.901761

# %%
sport.plot_accuracy_predictions(sport.df['Price'],sport.df['Predicted_Price'])

# %%
sport.deal_type()

# %%
sport.plot_deals(x='Price',y='Predicted_Price',hue='Deal_type',title='Great Deals on Motorbikes')

# %%
sport.df.drop(['Predicted_Price','Price_ratio','Deal_type'],axis=1, inplace=True)

# %%
bike_cols = [col for col in sport.df.columns if 'Bike' in col]
brand_cols = [col for col in sport.df.columns if 'Brand' in col]
model_cols = [col for col in sport.df.columns if 'Model' in col]
niave_feature = ['Kilometers','Age']

# %%
def run_pipeline(features=None):
    
    sport = bikeSales()
    sport.read_data()
    sport.add_dummy_variables()
    
    if (features == None):
        features = list(set(sport.df.columns) - set(['Price']))
        
    sport.find_best_model(features, sport.df['Price'])
    print ('Model: ',sport.model['Model'])
    print ('Score: ',sport.model['Score'])

    print ('Feature selection process.')
    sport.feature_selection(features)
    print ('Score: ',sport.model['Score'])
    
    # Optimise model parameters
    
    # Fit the full model
    sport.fit(sport.df[sport.model['Features']],sport.df['Price'])
    # Make predictions
    predictions = sport.predict(sport.df[sport.model['Features']])
    sport.df['Predicted_Price'] = predictions
    
    # Determine the deal type
    sport.deal_type()

    # Display the predicted deals
    sport.plot_deals(x='Price',y='Predicted_Price',hue='Deal_type',title='Great Deals on Motorbikes')
    
    return sport

# %%
niave = run_pipeline(niave_feature)
# Out:
# Model:  RidgeCV(alphas=array([ 0.1,  1. , 10. ]), cv=5, fit_intercept=True,
#     gcv_mode=None, normalize=False, scoring=None, store_cv_values=False)
# Score:  0.11380941145674502
# Feature selection process.
# Added feature: Kilometers with adjusted R^2 = 0.132
# Added feature: Age with adjusted R^2 = 0.138
#
# Resulting features:
# Kilometers, Age
# Score:  0.13756867243380233

# %%
bikes = run_pipeline(bike_cols)
# Out:
# Model:  RidgeCV(alphas=array([ 0.1,  1. , 10. ]), cv=5, fit_intercept=True,
#     gcv_mode=None, normalize=False, scoring=None, store_cv_values=False)
# Score:  0.7152106467726063
# Feature selection process.
# Added feature: Bike_959 Panigale Road Manual 6sp 959cc with adjusted R^2 = 0.0514
# Added feature: Bike_GSX-R1000R Road Manual 6sp 1000cc with adjusted R^2 = 0.106
# Added feature: Bike_S 1000 RR Road Manual 6sp 1000cc with adjusted R^2 = 0.153
# Added feature: Bike_YZF-R1M Road Manual 6sp 1000cc with adjusted R^2 = 0.201
# Added feature: Bike_1199 Panigale S Road Manual 6sp 1200cc with adjusted R^2 = 0.243
# Added feature: Bike_Ninja ZX-10R KRT ABS Replica Road Manual 6sp 1000cc with adjusted R^2 = 0.274
# Added feature: Bike_Ninja 250R  Road Manual 6sp 250cc with adjusted R^2 = 0.304
# Added feature: Bike_CBR250R Road Manual 6sp 250cc with adjusted R^2 = 0.327
# Added feature: Bike_YZF-R3 Road Manual 6sp 300cc with adjusted R^2 = 0.345
# Added feature: Bike_GSX-R1000 ABS MY17 Road Manual 6sp with adjusted R^2 = 0.362
# Added feature: Bike_F3 800 RC MY19 Road Manual 6sp with adjusted R^2 = 0.378
# Added feature: Bike_1199 Panigale R ABS Road Manual 1198cc with adjusted R^2 = 0.393
# Added feature: Bike_Ninja H2  Road Manual 6sp 1000cc with adjusted R^2 = 0.408
# Added feature: Bike_Hayabusa  Road Manual 6sp 1300cc with adjusted R^2 = 0.422
# Added feature: Bike_1198 S Road Manual 6sp 1198cc with adjusted R^2 = 0.435
# Added feature: Bike_S 1000 RR MY16 Road Manual 6sp with adjusted R^2 = 0.448
# Added feature: Bike_1199 Panigale S Tricolore Road 1199cc with adjusted R^2 = 0.46
# Added feature: Bike_SuperSport S Road Manual 6sp 950cc with adjusted R^2 = 0.472
# Added feature: Bike_Ninja ZX-10RR  Road Manual 6sp 1000cc with adjusted R^2 = 0.484
# Added feature: Bike_1199 Panigale Road Manual 6sp with adjusted R^2 = 0.496
# Added feature: Bike_Ninja ZX-10R ABS Road Manual 6sp 1000cc with adjusted R^2 = 0.508
# Added feature: Bike_Ninja ZX-10R ABS MY17 Road Manual 6sp with adjusted R^2 = 0.52
# Added feature: Bike_1198 S Corse Edition with adjusted R^2 = 0.53
# Added feature: Bike_YZF-R1 Road Manual 6sp 1000cc with adjusted R^2 = 0.541
# Added feature: Bike_SuperSport Road Manual 6sp 937cc with adjusted R^2 = 0.551
# Added feature: Bike_899 Panigale Road Manual 899cc with adjusted R^2 = 0.561
# Added feature: Bike_YZF-R1 MY19 Road Manual 6sp with adjusted R^2 = 0.57
# Added feature: Bike_S 1000 RR Sport Road Manual 6sp 1000cc with adjusted R^2 = 0.579
# Added feature: Bike_CBR250R ABS Road Manual 6sp 250cc with adjusted R^2 = 0.586
# Added feature: Bike_F3 800 Road Manual 800cc with adjusted R^2 = 0.593
# Added feature: Bike_RSV4 R APRC ABS Road Manual 1000cc with adjusted R^2 = 0.6
# Added feature: Bike_CBR1000RR FireBlade Road Manual 6sp 1000cc with adjusted R^2 = 0.606
# Added feature: Bike_S 1000 RR Race Road Manual 6sp 1000cc with adjusted R^2 = 0.612
# Added feature: Bike_959 Panigale MY19 Road Manual 6sp with adjusted R^2 = 0.618
# Added feature: Bike_F4 1000 ABS Road Manual 1000cc with adjusted R^2 = 0.624
# Added feature: Bike_GSX-R1000 MY16 Road Manual 6sp with adjusted R^2 = 0.63
# Added feature: Bike_848 EVO Road Manual 6sp 849cc with adjusted R^2 = 0.635
# Added feature: Bike_GSX-R1000 ABS MY16 Road Manual 6sp with adjusted R^2 = 0.64
# Added feature: Bike_GSX-R1000 Road Manual 6sp 1000cc with adjusted R^2 = 0.644
# Added feature: Bike_CBR1000RRA ABS Fireblade Road Manual 6sp 1000cc with adjusted R^2 = 0.648
# Added feature: Bike_Ninja ZX-14R ABS MY16 Road Manual with adjusted R^2 = 0.651
# Added feature: Bike_Ninja 250R MY11 Road Manual 6sp with adjusted R^2 = 0.655
# Added feature: Bike_CBR500R Road Manual 500cc with adjusted R^2 = 0.658
# Added feature: Bike_Ninja 300 ABS Special Edition Road Manual 300cc with adjusted R^2 = 0.661
# Added feature: Bike_CBR500RA  Road Manual 500cc with adjusted R^2 = 0.665
# Added feature: Bike_Ninja 250R MY10 Road Manual 6sp with adjusted R^2 = 0.668
# Added feature: Bike_VTR1000SP2 Road Manual 6sp 1000cc with adjusted R^2 = 0.671
# Added feature: Bike_Ninja 300 ABS  Road Manual 300cc with adjusted R^2 = 0.673
# Added feature: Bike_Ninja 250R MY09 Road Manual 6sp with adjusted R^2 = 0.676
# Added feature: Bike_Ninja 300 Special Edition Road Manual 300cc with adjusted R^2 = 0.679
# Added feature: Bike_CBR500R MY14 Road Manual with adjusted R^2 = 0.681
# Added feature: Bike_CBR300R Road Manual 300cc with adjusted R^2 = 0.684
# Added feature: Bike_CBR500RA  Road Manual 6sp 500cc with adjusted R^2 = 0.686
# Added feature: Bike_GSX-R600 with adjusted R^2 = 0.689
# Added feature: Bike_CBR300R ABS  Road Manual 300cc with adjusted R^2 = 0.692
# Added feature: Bike_CBR600F4i Road Manual 6sp 600cc with adjusted R^2 = 0.694
# Added feature: Bike_GT650R EFI Road Manual 6sp 650cc with adjusted R^2 = 0.697
# Added feature: Bike_Ninja ZX-6R  Road Manual 6sp 600cc with adjusted R^2 = 0.699
# Added feature: Bike_Ninja 250R MY12 Road Manual 6sp with adjusted R^2 = 0.701
# Added feature: Bike_YZF-R15 MY15 Road Manual 6sp with adjusted R^2 = 0.703
# Added feature: Bike_RSV4 Factory APRC ABS Road Manual 6sp 1000cc with adjusted R^2 = 0.705
# Added feature: Bike_Ninja ZX-14R ABS Special Edition  Road Manual 6sp 1400cc with adjusted R^2 = 0.707
# Added feature: Bike_Road Manual 6sp 916cc with adjusted R^2 = 0.709
# Added feature: Bike_Ninja 300 ABS MY14 Road Manual with adjusted R^2 = 0.711
# Added feature: Bike_Ninja 300 Special Edition MY13 Road Manual with adjusted R^2 = 0.713
# Added feature: Bike_YZF-R15 Road Manual 6sp 150cc with adjusted R^2 = 0.714
# Added feature: Bike_Ninja 300 ABS MY13 Road Manual with adjusted R^2 = 0.716
# Added feature: Bike_YZF-R6 Road Manual 6sp 600cc with adjusted R^2 = 0.718
# Added feature: Bike_ZX-12R Road Manual 6sp 1200cc with adjusted R^2 = 0.719
# Added feature: Bike_CBR300R ABS MY15 Road Manual with adjusted R^2 = 0.721
# Added feature: Bike_YZF-R3 MY18 Road Manual 6sp with adjusted R^2 = 0.722
# Added feature: Bike_Ninja 300 SE KRT Replica  Road Manual 6sp 300cc with adjusted R^2 = 0.724
# Added feature: Bike_CBR300R ABS MY17 Road Manual with adjusted R^2 = 0.725
# Added feature: Bike_CBR500RA MY17 Road Manual with adjusted R^2 = 0.726
# Added feature: Bike_Ninja 300 ABS MY16 Road Manual with adjusted R^2 = 0.728
# Added feature: Bike_GSX-R1000  GSX-R1000 - 988cc with adjusted R^2 = 0.729
# Added feature: Bike_Ninja 300 ABS MY17 Road Manual with adjusted R^2 = 0.731
# Added feature: Bike_CBR600RR Road Manual 6sp 599cc with adjusted R^2 = 0.732
# Added feature: Bike_YZF-R15 Road Manual 5sp 150cc with adjusted R^2 = 0.734
# Added feature: Bike_Daytona 675 Road Manual 6sp 675cc with adjusted R^2 = 0.735
# Added feature: Bike_Ninja ZX-6R  Road Manual 6sp 636cc with adjusted R^2 = 0.736
# Added feature: Bike_YZF-R3 MY17 Road Manual 6sp with adjusted R^2 = 0.738
# Added feature: Bike_CBR250R SE Mugen Road Manual 250cc with adjusted R^2 = 0.739
# Added feature: Bike_CBR954RR Fireblade with adjusted R^2 = 0.74
# Added feature: Bike_Ninja 300 ABS Special Edition MY13 Road Manual with adjusted R^2 = 0.741
# Added feature: Bike_YZF-R15 MY12 Road Manual 6sp with adjusted R^2 = 0.743
# Added feature: Bike_GSX-R750 Road Manual 6sp 750cc with adjusted R^2 = 0.744
# Added feature: Bike_CBR300R ABS SE  Road Manual 6sp 300cc with adjusted R^2 = 0.745
# Added feature: Bike_RS4 125  Road Manual 6sp 125cc with adjusted R^2 = 0.746
# Added feature: Bike_Ninja 300 ABS SE 30th Anniversary Road Manual 6sp 300cc with adjusted R^2 = 0.747
# Added feature: Bike_Ninja 300 Special Edition MY14 Road Manual with adjusted R^2 = 0.749
# Added feature: Bike_Ninja 300 ABS Special Edition MY15 Road Manual with adjusted R^2 = 0.75
# Added feature: Bike_GSX-R750 20th Anniversary  Road Manual 750cc with adjusted R^2 = 0.751
# Added feature: Bike_GSX-R1000 MY08 Road Manual 6sp with adjusted R^2 = 0.752
# Added feature: Bike_CBR954RR Fireblade Road Manual 6sp 954cc with adjusted R^2 = 0.753
# Added feature: Bike_CBR650F LAMS with adjusted R^2 = 0.754
# Added feature: Bike_GSX250R MY18 Road Manual 6sp with adjusted R^2 = 0.755
# Added feature: Bike_RSV1000 Mille Road Manual 6sp 1000cc with adjusted R^2 = 0.756
# Added feature: Bike_GSX-R750 MY09 Road Manual 6sp with adjusted R^2 = 0.757
# Added feature: Bike_Ninja 300 ABS Special Edition MY16 Road Manual with adjusted R^2 = 0.758
# Added feature: Bike_CBR300R MY15 Road Manual with adjusted R^2 = 0.759
# Added feature: Bike_Daytona 675 SE Road Manual 6sp 675cc with adjusted R^2 = 0.76
# Added feature: Bike_CBR900RR Fireblade with adjusted R^2 = 0.76
# Added feature: Bike_CBR600RR Telefonica Road Manual 6sp 599cc with adjusted R^2 = 0.761
# Added feature: Bike_Ninja ZX-6R MY10 Road Manual 6sp with adjusted R^2 = 0.762
# Added feature: Bike_Ninja 250R Special Edition Road Manual 6sp 250cc with adjusted R^2 = 0.763
# Added feature: Bike_GSX-R600 Road Manual 6sp 600cc with adjusted R^2 = 0.764
# Added feature: Bike_GSX250R Road Manual 6sp 250cc with adjusted R^2 = 0.764
# Added feature: Bike_ZX-7R Ninja  Road Manual 6sp 750cc with adjusted R^2 = 0.765
# Added feature: Bike_CBR500RA MY14 Road Manual with adjusted R^2 = 0.766
# Added feature: Bike_Panigale V4 Road Manual 6sp 1100cc with adjusted R^2 = 0.766
# Added feature: Bike_Ninja ZX-10R Road Manual 6sp 1000cc with adjusted R^2 = 0.767
# Added feature: Bike_Ninja 400 KRT Edition MY19 Road Manual 6sp with adjusted R^2 = 0.768
# Added feature: Bike_YZF-R1 MY17 Road Manual 6sp with adjusted R^2 = 0.768
# Added feature: Bike_Ninja ZX-10R MY10 Road Manual 6sp with adjusted R^2 = 0.768
# Added feature: Bike_1098S Tri Colore Road Manual 6sp 1098cc with adjusted R^2 = 0.769
# Added feature: Bike_CBR600RR MY12 Road Manual 6sp with adjusted R^2 = 0.769
# Added feature: Bike_Road Manual 6sp 749cc with adjusted R^2 = 0.769
# Added feature: Bike_YZF-R1 MY10 Road Manual 6sp with adjusted R^2 = 0.769
# Added feature: Bike_CBR600RR MY13 Road Manual 6sp with adjusted R^2 = 0.77
# Added feature: Bike_CBR650F LAMS  Road Manual 6sp 650cc with adjusted R^2 = 0.77
# Added feature: Bike_Road Manual 6sp 848cc with adjusted R^2 = 0.77
# Added feature: Bike_MY13 Daytona 675 with adjusted R^2 = 0.77
# Added feature: Bike_Ninja ZX-14R ABS Special Edition  Road Manual 1400cc  ZX1400FEFA) with adjusted R^2 = 0.77
# Added feature: Bike_YZF-R1M MY19 Road Manual 6sp with adjusted R^2 = 0.77
#
# Resulting features:
# Bike_959 Panigale Road Manual 6sp 959cc, Bike_GSX-R1000R Road Manual 6sp 1000cc, Bike_S 1000 RR Road Manual 6sp 1000cc, Bike_YZF-R1M Road Manual 6sp 1000cc, Bike_1199 Panigale S Road Manual 6sp 1200cc, Bike_Ninja ZX-10R KRT ABS Replica Road Manual 6sp 1000cc, Bike_Ninja 250R  Road Manual 6sp 250cc, Bike_CBR250R Road Manual 6sp 250cc, Bike_YZF-R3 Road Manual 6sp 300cc, Bike_GSX-R1000 ABS MY17 Road Manual 6sp, Bike_F3 800 RC MY19 Road Manual 6sp, Bike_1199 Panigale R ABS Road Manual 1198cc, Bike_Ninja H2  Road Manual 6sp 1000cc, Bike_Hayabusa  Road Manual 6sp 1300cc, Bike_1198 S Road Manual 6sp 1198cc, Bike_S 1000 RR MY16 Road Manual 6sp, Bike_1199 Panigale S Tricolore Road 1199cc, Bike_SuperSport S Road Manual 6sp 950cc, Bike_Ninja ZX-10RR  Road Manual 6sp 1000cc, Bike_1199 Panigale Road Manual 6sp, Bike_Ninja ZX-10R ABS Road Manual 6sp 1000cc, Bike_Ninja ZX-10R ABS MY17 Road Manual 6sp, Bike_1198 S Corse Edition, Bike_YZF-R1 Road Manual 6sp 1000cc, Bike_SuperSport Road Manual 6sp 937cc, Bike_899 Panigale Road Manual 899cc, Bike_YZF-R1 MY19 Road Manual 6sp, Bike_S 1000 RR Sport Road Manual 6sp 1000cc, Bike_CBR250R ABS Road Manual 6sp 250cc, Bike_F3 800 Road Manual 800cc, Bike_RSV4 R APRC ABS Road Manual 1000cc, Bike_CBR1000RR FireBlade Road Manual 6sp 1000cc, Bike_S 1000 RR Race Road Manual 6sp 1000cc, Bike_959 Panigale MY19 Road Manual 6sp, Bike_F4 1000 ABS Road Manual 1000cc, Bike_GSX-R1000 MY16 Road Manual 6sp, Bike_848 EVO Road Manual 6sp 849cc, Bike_GSX-R1000 ABS MY16 Road Manual 6sp, Bike_GSX-R1000 Road Manual 6sp 1000cc, Bike_CBR1000RRA ABS Fireblade Road Manual 6sp 1000cc, Bike_Ninja ZX-14R ABS MY16 Road Manual, Bike_Ninja 250R MY11 Road Manual 6sp, Bike_CBR500R Road Manual 500cc, Bike_Ninja 300 ABS Special Edition Road Manual 300cc, Bike_CBR500RA  Road Manual 500cc, Bike_Ninja 250R MY10 Road Manual 6sp, Bike_VTR1000SP2 Road Manual 6sp 1000cc, Bike_Ninja 300 ABS  Road Manual 300cc, Bike_Ninja 250R MY09 Road Manual 6sp, Bike_Ninja 300 Special Edition Road Manual 300cc, Bike_CBR500R MY14 Road Manual, Bike_CBR300R Road Manual 300cc, Bike_CBR500RA  Road Manual 6sp 500cc, Bike_GSX-R600, Bike_CBR300R ABS  Road Manual 300cc, Bike_CBR600F4i Road Manual 6sp 600cc, Bike_GT650R EFI Road Manual 6sp 650cc, Bike_Ninja ZX-6R  Road Manual 6sp 600cc, Bike_Ninja 250R MY12 Road Manual 6sp, Bike_YZF-R15 MY15 Road Manual 6sp, Bike_RSV4 Factory APRC ABS Road Manual 6sp 1000cc, Bike_Ninja ZX-14R ABS Special Edition  Road Manual 6sp 1400cc, Bike_Road Manual 6sp 916cc, Bike_Ninja 300 ABS MY14 Road Manual, Bike_Ninja 300 Special Edition MY13 Road Manual, Bike_YZF-R15 Road Manual 6sp 150cc, Bike_Ninja 300 ABS MY13 Road Manual, Bike_YZF-R6 Road Manual 6sp 600cc, Bike_ZX-12R Road Manual 6sp 1200cc, Bike_CBR300R ABS MY15 Road Manual, Bike_YZF-R3 MY18 Road Manual 6sp, Bike_Ninja 300 SE KRT Replica  Road Manual 6sp 300cc, Bike_CBR300R ABS MY17 Road Manual, Bike_CBR500RA MY17 Road Manual, Bike_Ninja 300 ABS MY16 Road Manual, Bike_GSX-R1000  GSX-R1000 - 988cc, Bike_Ninja 300 ABS MY17 Road Manual, Bike_CBR600RR Road Manual 6sp 599cc, Bike_YZF-R15 Road Manual 5sp 150cc, Bike_Daytona 675 Road Manual 6sp 675cc, Bike_Ninja ZX-6R  Road Manual 6sp 636cc, Bike_YZF-R3 MY17 Road Manual 6sp, Bike_CBR250R SE Mugen Road Manual 250cc, Bike_CBR954RR Fireblade, Bike_Ninja 300 ABS Special Edition MY13 Road Manual, Bike_YZF-R15 MY12 Road Manual 6sp, Bike_GSX-R750 Road Manual 6sp 750cc, Bike_CBR300R ABS SE  Road Manual 6sp 300cc, Bike_RS4 125  Road Manual 6sp 125cc, Bike_Ninja 300 ABS SE 30th Anniversary Road Manual 6sp 300cc, Bike_Ninja 300 Special Edition MY14 Road Manual, Bike_Ninja 300 ABS Special Edition MY15 Road Manual, Bike_GSX-R750 20th Anniversary  Road Manual 750cc, Bike_GSX-R1000 MY08 Road Manual 6sp, Bike_CBR954RR Fireblade Road Manual 6sp 954cc, Bike_CBR650F LAMS, Bike_GSX250R MY18 Road Manual 6sp, Bike_RSV1000 Mille Road Manual 6sp 1000cc, Bike_GSX-R750 MY09 Road Manual 6sp, Bike_Ninja 300 ABS Special Edition MY16 Road Manual, Bike_CBR300R MY15 Road Manual, ...
# Score:  0.7702601581090315

# %%
brands = run_pipeline(brand_cols)
# Out:
# Model:  BaggingRegressor(base_estimator=None, bootstrap=True,
#          bootstrap_features=False, max_features=1.0, max_samples=1.0,
#          n_estimators=10, n_jobs=None, oob_score=False, random_state=None,
#          verbose=0, warm_start=False)
# Score:  0.36140698426159873
# Feature selection process.
# Added feature: Brand_Ducati with adjusted R^2 = 0.161
# Added feature: Brand_Bmw with adjusted R^2 = 0.258
# Added feature: Brand_Suzuki with adjusted R^2 = 0.292
# Added feature: Brand_MV Agusta with adjusted R^2 = 0.323
# Added feature: Brand_Honda with adjusted R^2 = 0.332
# Added feature: Brand_Bimota with adjusted R^2 = 0.341
# Added feature: Brand_Kawasaki with adjusted R^2 = 0.345
# Added feature: Brand_Hyosung with adjusted R^2 = 0.348
# Added feature: Brand_Aprilia with adjusted R^2 = 0.35
# Added feature: Brand_Jiajue with adjusted R^2 = 0.351
#
# Resulting features:
# Brand_Ducati, Brand_Bmw, Brand_Suzuki, Brand_MV Agusta, Brand_Honda, Brand_Bimota, Brand_Kawasaki, Brand_Hyosung, Brand_Aprilia, Brand_Jiajue
# Score:  0.35119185225550476

# %%
models = run_pipeline(model_cols)
# Out:
# Model:  RidgeCV(alphas=array([ 0.1,  1. , 10. ]), cv=5, fit_intercept=True,
#     gcv_mode=None, normalize=False, scoring=None, store_cv_values=False)
# Score:  0.727625216188839
# Feature selection process.
# Added feature: Model_959 panigale with adjusted R^2 = 0.0567
# Added feature: Model_S 1000 rr with adjusted R^2 = 0.115
# Added feature: Model_Gsx r1000r with adjusted R^2 = 0.171
# Added feature: Model_Yzf r1m with adjusted R^2 = 0.225
# Added feature: Model_Ninja 250r ex250j with adjusted R^2 = 0.273
# Added feature: Model_1199 panigale s with adjusted R^2 = 0.314
# Added feature: Model_Ninja zx 10r krt abs replica with adjusted R^2 = 0.345
# Added feature: Model_Cbr250r with adjusted R^2 = 0.369
# Added feature: Model_Yzf r3 with adjusted R^2 = 0.391
# Added feature: Model_Cbr500ra abs with adjusted R^2 = 0.413
# Added feature: Model_Ninja 300 abs ex300b with adjusted R^2 = 0.432
# Added feature: Model_Cbr500r with adjusted R^2 = 0.453
# Added feature: Model_Gsx r1000 abs with adjusted R^2 = 0.469
# Added feature: Model_S 1000 rr race with adjusted R^2 = 0.485
# Added feature: Model_f3 800 rc with adjusted R^2 = 0.499
# Added feature: Model_1199 panigale r abs with adjusted R^2 = 0.514
# Added feature: Model_Ninja h2 zx1000n with adjusted R^2 = 0.528
# Added feature: Model_Ninja zx 10r abs with adjusted R^2 = 0.542
# Added feature: Model_1199 panigale with adjusted R^2 = 0.556
# Added feature: Model_Cbr250r abs with adjusted R^2 = 0.568
# Added feature: Model_Ninja 300 abs special edition with adjusted R^2 = 0.581
# Added feature: Model_1198 s with adjusted R^2 = 0.593
# Added feature: Model_Ninja zx 10rr zx1000z with adjusted R^2 = 0.604
# Added feature: Model_Hayabusa gsx1300r with adjusted R^2 = 0.615
# Added feature: Model_1199 panigale s tricolore with adjusted R^2 = 0.626
# Added feature: Model_Supersport s with adjusted R^2 = 0.637
# Added feature: Model_1198 s corse edition with adjusted R^2 = 0.647
# Added feature: Model_Cbr300r abs cbr300ra with adjusted R^2 = 0.656
# Added feature: Model_Ninja 300 special edition with adjusted R^2 = 0.664
# Added feature: Model_Yzf r15 with adjusted R^2 = 0.673
# Added feature: Model_f3 800 with adjusted R^2 = 0.681
# Added feature: Model_Supersport with adjusted R^2 = 0.689
# Added feature: Model_Yzf r1 with adjusted R^2 = 0.696
# Added feature: Model_899 panigale with adjusted R^2 = 0.704
# Added feature: Model_S 1000 rr sport with adjusted R^2 = 0.709
# Added feature: Model_f4 1000 abs with adjusted R^2 = 0.713
# Added feature: Model_Rsv4 r aprc abs with adjusted R^2 = 0.718
# Added feature: Model_Cbr300r with adjusted R^2 = 0.722
# Added feature: Model_Gt650r efi with adjusted R^2 = 0.726
# Added feature: Model_Cbr600f4i with adjusted R^2 = 0.73
# Added feature: Model_Gsx r600 with adjusted R^2 = 0.734
# Added feature: Model_Ninja zx 6r zx600 with adjusted R^2 = 0.737
# Added feature: Model_Cbr250ra abs se repsol with adjusted R^2 = 0.74
# Added feature: Model_Ninja zx 6r zx600r with adjusted R^2 = 0.742
# Added feature: Model_Yzf r6 with adjusted R^2 = 0.745
# Added feature: Model_Zx 12r with adjusted R^2 = 0.747
# Added feature: Model_Cbr954rr fireblade with adjusted R^2 = 0.749
# Added feature: Model_Ninja zx 6r zx636 with adjusted R^2 = 0.751
# Added feature: Model_Cbr600rr with adjusted R^2 = 0.753
# Added feature: Model_Daytona 675 with adjusted R^2 = 0.756
# Added feature: Model_Gsx r750 with adjusted R^2 = 0.758
# Added feature: Model_Gsx r1000 988cc with adjusted R^2 = 0.761
# Added feature: Model_Ninja 300 se krt replica ex300a with adjusted R^2 = 0.763
# Added feature: Model_Ninja zx 10r with adjusted R^2 = 0.765
# Added feature: Model_Gsx250r with adjusted R^2 = 0.767
# Added feature: Model_Cbr250r se mugen with adjusted R^2 = 0.769
# Added feature: Model_Rs4 125 4t with adjusted R^2 = 0.771
# Added feature: Model_Cbr650f lams cbr650fl with adjusted R^2 = 0.772
# Added feature: Model_Cbr300r abs se cbr300rase with adjusted R^2 = 0.774
# Added feature: Model_Gsx r750 20th anniversary gsx r750x with adjusted R^2 = 0.775
# Added feature: Model_Ninja 250r special edition with adjusted R^2 = 0.777
# Added feature: Model_Rsv1000 mille with adjusted R^2 = 0.778
# Added feature: Model_Daytona 675 se with adjusted R^2 = 0.779
# Added feature: Model_Ninja 300 abs se 30th anniversary with adjusted R^2 = 0.78
# Added feature: Model_Cbr900rr fireblade 929 with adjusted R^2 = 0.782
# Added feature: Model_Cbr1000rr fireblade with adjusted R^2 = 0.783
# Added feature: Model_Cbr600rr telefonica with adjusted R^2 = 0.784
# Added feature: Model_848 with adjusted R^2 = 0.785
# Added feature: Model_Zx 7r ninja zx750 with adjusted R^2 = 0.786
# Added feature: Model_Gsx r1000 with adjusted R^2 = 0.787
# Added feature: Model_Ninja 400 krt edition ex400g with adjusted R^2 = 0.788
# Added feature: Model_Gsx250rz with adjusted R^2 = 0.789
# Added feature: Model_Ninja zx 6r abs 636 with adjusted R^2 = 0.79
# Added feature: Model_Daytona 675 r with adjusted R^2 = 0.791
# Added feature: Model_Ninja zx 6r 636 with adjusted R^2 = 0.791
# Added feature: Model_Ninja zx 6r monster energy zx600r with adjusted R^2 = 0.792
# Added feature: Model_Cbr1000rra abs fireblade with adjusted R^2 = 0.792
# Added feature: Model_Rsv4 factory aprc abs with adjusted R^2 = 0.792
# Added feature: Model_916 with adjusted R^2 = 0.792
#
# Resulting features:
# Model_959 panigale, Model_S 1000 rr, Model_Gsx r1000r, Model_Yzf r1m, Model_Ninja 250r ex250j, Model_1199 panigale s, Model_Ninja zx 10r krt abs replica, Model_Cbr250r, Model_Yzf r3, Model_Cbr500ra abs, Model_Ninja 300 abs ex300b, Model_Cbr500r, Model_Gsx r1000 abs, Model_S 1000 rr race, Model_f3 800 rc, Model_1199 panigale r abs, Model_Ninja h2 zx1000n, Model_Ninja zx 10r abs, Model_1199 panigale, Model_Cbr250r abs, Model_Ninja 300 abs special edition, Model_1198 s, Model_Ninja zx 10rr zx1000z, Model_Hayabusa gsx1300r, Model_1199 panigale s tricolore, Model_Supersport s, Model_1198 s corse edition, Model_Cbr300r abs cbr300ra, Model_Ninja 300 special edition, Model_Yzf r15, Model_f3 800, Model_Supersport, Model_Yzf r1, Model_899 panigale, Model_S 1000 rr sport, Model_f4 1000 abs, Model_Rsv4 r aprc abs, Model_Cbr300r, Model_Gt650r efi, Model_Cbr600f4i, Model_Gsx r600, Model_Ninja zx 6r zx600, Model_Cbr250ra abs se repsol, Model_Ninja zx 6r zx600r, Model_Yzf r6, Model_Zx 12r, Model_Cbr954rr fireblade, Model_Ninja zx 6r zx636, Model_Cbr600rr, Model_Daytona 675, Model_Gsx r750, Model_Gsx r1000 988cc, Model_Ninja 300 se krt replica ex300a, Model_Ninja zx 10r, Model_Gsx250r, Model_Cbr250r se mugen, Model_Rs4 125 4t, Model_Cbr650f lams cbr650fl, Model_Cbr300r abs se cbr300rase, Model_Gsx r750 20th anniversary gsx r750x, Model_Ninja 250r special edition, Model_Rsv1000 mille, Model_Daytona 675 se, Model_Ninja 300 abs se 30th anniversary, Model_Cbr900rr fireblade 929, Model_Cbr1000rr fireblade, Model_Cbr600rr telefonica, Model_848, Model_Zx 7r ninja zx750, Model_Gsx r1000, Model_Ninja 400 krt edition ex400g, Model_Gsx250rz, Model_Ninja zx 6r abs 636, Model_Daytona 675 r, Model_Ninja zx 6r 636, Model_Ninja zx 6r monster energy zx600r, Model_Cbr1000rra abs fireblade, Model_Rsv4 factory aprc abs, Model_916
# Score:  0.7920368979888663

# %%
allFeatures = run_pipeline()
# Out:
# Model:  BaggingRegressor(base_estimator=None, bootstrap=True,
#          bootstrap_features=False, max_features=1.0, max_samples=1.0,
#          n_estimators=10, n_jobs=None, oob_score=False, random_state=None,
#          verbose=0, warm_start=False)
# Score:  0.8858539312868963
# Feature selection process.
# Added feature: Stroke with adjusted R^2 = 0.677
# Added feature: Live_Add with adjusted R^2 = 0.863
# Added feature: Dry_Weight with adjusted R^2 = 0.899
# Added feature: Seat_Height with adjusted R^2 = 0.909
# Added feature: Kilometers with adjusted R^2 = 0.92
# Added feature: Wheelbase with adjusted R^2 = 0.929
# Added feature: Model_Rsv4 r aprc abs with adjusted R^2 = 0.939
#
# Resulting features:
# Stroke, Live_Add, Dry_Weight, Seat_Height, Kilometers, Wheelbase, Model_Rsv4 r aprc abs
# Score:  0.9387480512542409

# %%
print (len(allFeatures.model['Features']))
# Out:
# 7

# %%
# ALL Features
sport = bikeSales()
    
sport.read_data()

# %%
sport.add_dummy_variables()

# %%
features = list(set(sport.df.columns) - set(['Price']))
        
sport.find_best_model(features, sport.df['Price'])
print ('Model: ',sport.model['Model'])
print ('Score: ',sport.model['Score'])
# Out:
# Model:  BaggingRegressor(base_estimator=None, bootstrap=True,
#          bootstrap_features=False, max_features=1.0, max_samples=1.0,
#          n_estimators=10, n_jobs=None, oob_score=False, random_state=None,
#          verbose=0, warm_start=False)
# Score:  0.886221705203659

# %%
len(sport.model['Features'])
# Out:
# 642

# %%
print ('Feature selection process.')
sport.feature_selection(features)
print ('Score: ',sport.model['Score'])
print ('Features: ',sport.model['Features'])
# Out:
# Feature selection process.
# Added feature: Stroke with adjusted R^2 = 0.679
# Added feature: Age with adjusted R^2 = 0.856
# Added feature: Trail with adjusted R^2 = 0.887
# Added feature: Country_of_Origin_UNITED KINGDOM with adjusted R^2 = 0.902
# Added feature: Model_Yzf r1m with adjusted R^2 = 0.904
# Added feature: Bike_GSX-R1000R Road Manual 6sp 1000cc with adjusted R^2 = 0.912
# Added feature: Registration_Expiry_01/11/2018 with adjusted R^2 = 0.913
# Added feature: Carburettor_Carburettor with adjusted R^2 = 0.914
# Added feature: Registration_Expiry_01/06/2020 with adjusted R^2 = 0.915
#
# Resulting features:
# Stroke, Age, Trail, Country_of_Origin_UNITED KINGDOM, Model_Yzf r1m, Bike_GSX-R1000R Road Manual 6sp 1000cc, Registration_Expiry_01/11/2018, Carburettor_Carburettor, Registration_Expiry_01/06/2020
# Score:  0.9153771829842046

# %%
sport.fit(sport.df[sport.model['Features']],sport.df['Price'])

# %%
predictions = sport.predict(sport.df[sport.model['Features']])
sport.df['Predicted_Price'] = predictions

# %%
sport.deal_type()

# %%
sport.plot_deals(x='Price',y='Predicted_Price',hue='Deal_type',title='Great Deals on Motorbikes')

# %%
len(sport_df.columns)
# Out:
# 642

# %%
sport_df = sport.df
#sport_df.drop(['Predicted_Price','Price_ratio','Deal_type'],axis=1, inplace=True)
print(len(sport_df.columns))


features = list(set(sport_df.select_dtypes(include='number').columns) - set([target]))
features
# Out:
# 643
# ['Bike_GSX-R1000 25th Anniversary Edition Road Manual 6sp 1000cc',
#  'Bike_Ninja ZX-6R ABS 30th Anniversary MY15 Road Manual 6sp',
#  'Bike_Ninja 300 Special Edition MY14 Road Manual',
#  'Registration_Expiry_01/01/2019',
#  'Brand_Honda',
#  'Colour_purple',
#  'Bike_F3 800 RC MY15 Road Manual 6sp',
#  'Bike_Ninja 300 ABS MY17 Road Manual',
#  'Bike_F4 RR Road Manual 1000cc',
#  'Model_Ninja zx 10rr zx1000z',
#  'Model_Daytona 675 r',
#  'Starter_Kick',
#  'Registration_Expiry_01/11/2017',
#  'Warranty_KMs_No',
#  'Bike_Ninja ZX-6R ABS  Road Manual 6spd 600cc',
#  'Bike_GSX-R750 MY09 Road Manual 6sp',
#  'Colour_none',
#  'Cooling_Liquid & Fan',
#  'Front_Suspension_Travel',
#  'Bike_YZF-R6 MY17 Road Manual 6sp',
#  'Registration_Expiry_01/08/2018',
#  'Model_Motrac sp250',
#  'Bike_CBR1000RR  Road Manual 6sp 1000cc',
#  'Bike_GSX250R MY18 Road Manual 6sp',
#  'Exhaust_Config_2 into 2',
#  'Country_of_Origin_UNITED KINGDOM',
#  'Model_Ninja zx 10r krt abs replica',
#  'Bike_RSV4 R APRC ABS Road Manual 1000cc',
#  'Bike_Ninja ZX-6R Monster Energy MY10 Road Manual 6sp',
#  'Model_Cbr250r',
#  'Bike_YZF-R6 Road Manual 6sp 600cc',
#  'Bike_GSX-R1000 Limited Edition MotoGP Road Manual 6sp 1000cc',
#  'Bike_GSX-R750 MY17 Road Manual 6sp',
#  'Bike_S 1000 RR Sport MY18 Road Manual 6sp',
#  'Bike_YZF-R3 MY19 Road Manual 6sp',
#  'Bike_GSX-R600 Road Manual 6sp 599cc',
#  'Bike_CBR650F LAMS',
#  'Brand_Suzuki',
#  'Model_Cbr250r abs',
#  'Model_Gsx r1000 30th anniversary edition',
#  'Bike_Ninja H2  Road Manual 6sp 1000cc',
#  'Bike_CBR250R MY13 Road Manual 6sp',
#  'Wheel_Type_Other',
#  'Model_Cbr600rr telefonica',
#  'Brand_Aprilia',
#  'Model_Cbr1000rr fireblade',
#  'Model_800 sport half fairing',
#  'Rear_Suspension_Adjustable',
#  'Bike_YZF-R1 MY10 Road Manual 6sp',
#  'Model_Cbr1000rr repsol',
#  'Bike_1199 Panigale MY14 Road Manual',
#  'Kilometers',
#  'Bike_CBR1000RRA ABS Fireblade Road Manual 6sp 1000cc',
#  'Bike_Road Manual 6sp 998cc',
#  'Exhaust_Config_1 into 1',
#  'Brand_Bimota',
#  'Bike_1098S Tri Colore Road Manual 6sp 1098cc',
#  'Bike_GSX-R1000 MY15 Road Manual 6sp',
#  'Bike_Ninja ZX-10R ABS MY13 Road Manual 6sp',
#  'Front_Brake_Description_Hydraulic',
#  'Registration_Expiry_01/10/2018',
#  'Bike_Ninja ZX-14R ABS  Road Manual 1400cc',
#  'Bike_Road Manual 6sp 848cc',
#  'Linked_Braking_System_Standard',
#  'Model_Ninja zx 10r',
#  'Bike_F4 1000 Road Manual 6sp 1000cc',
#  'Registration_Expiry_01/03/2018',
#  'Bike_Daytona 675 MY14 Road Manual 6sp',
#  'Bike_Panigale V4 Road Manual 6sp 1100cc',
#  'Bike_YZF-R15 Road Manual 5sp 150cc',
#  'Model_f4ago 1000',
#  'Bike_YZF-R3 MY17 Road Manual 6sp',
#  'Bike_CBR300R MY15 Road Manual',
#  'Model_Yzf r6sp',
#  'Bike_YZF-R1 Anniversary MY16 Road Manual 6sp',
#  'Bike_GSX-R1000 ABS MY16 Road Manual 6sp',
#  'Model_Ninja 400 ex400g',
#  'Exhaust_Config_4 into 1',
#  'Bike_Ninja ZX-14 Road Manual 6sp 1400cc',
#  'Model_1199 panigale',
#  'Bike_999S Biposto',
#  'Rear_Brake_Diameter',
#  'Carburettor_Carburettor',
#  'Bike_CBR600RR HANNspree Ten Kate Road Manual 600cc',
#  'Wheel_Type_Aluminium',
#  'Cooling_Air',
#  'Bike_Ninja ZX-14R ABS MY16 Road Manual',
#  'Brand_Jiajue',
#  'Model_Zx 12r',
#  'Bike_GSX-R1000R Road Manual 6sp 1000cc',
#  'Registration_Expiry_01/01/2020',
#  'Bike_YZF-R1M Road Manual 6sp 1000cc',
#  'Bike_1198 S Road Manual 6sp 1198cc',
#  'Bike_CBR250R SE Mugen Road Manual 250cc',
#  'Bike_Ninja ZX-6RR  Road Manual 6sp 600cc',
#  'Model_f4 750 s f4s 11',
#  'Bike_Ninja ZX-6R ABS MY16 Road Manual 6spd',
#  'Bike_959 Panigale Road Manual 6sp 959cc',
#  'Charging_Method_Engine',
#  'Bike_Ninja 250R Special Edition Road Manual 6sp 250cc',
#  'Registration_Expiry_01/02/2020',
#  'Bike_YZF-R15 MY12 Road Manual 6sp',
#  'Bike_YZF-R1M MY16 Road Manual 6sp',
#  'Model_Tt600',
#  'Bike_YZF-R1 Road Manual 6sp 1000cc',
#  'Bike_1199 Panigale S Tricolore Road 1199cc',
#  'Bike_Ninja 400 Special Edition MY19 Road Manual 6sp',
#  'Registration_Expiry_01/04/2019',
#  'Bike_S 1000 RR Sport',
#  'Rear_Brake_Caliper(s)_Triple Piston',
#  'Bike_Daytona 675 R MY12 Road Manual 6sp',
#  'Bike_F3 800 RC MY19 Road Manual 6sp',
#  'Registration_Expiry_01/10/2017',
#  'Frame_Material_Other',
#  'Engine_Type_Electric',
#  'Model_Ninja zx 10r abs krt winter edition zx1000s',
#  'Bike_Ninja ZX-10R KRT Replica  Road Manual 6sp 1000cc',
#  'Bike_Hayabusa  Road Manual 6sp 1300cc',
#  'Bike_Ninja 250R MY09 Road Manual 6sp',
#  'Model_Supersport',
#  'Bike_Ninja ZX-14R ABS Special Edition  Road Manual 6sp 1400cc',
#  'Clutch_Type_Multi plate',
#  'Model_Gsx250r',
#  'Rear_Suspension_Other',
#  'Model_S 1000 rr sport',
#  'Registration_Expiry_01/05/2016',
#  'Bike_CBR500RA  Road Manual 6sp 500cc',
#  'Engine_Config_Forward-Inclined',
#  'Exhaust_Config_4 into 4',
#  'Model_S 1000 rr m sport',
#  'Bike_Ninja 300 ABS SE 30th Anniversary Road Manual 6sp 300cc',
#  'Model_Gsx r1000',
#  'Registration_Expiry_01/12/2018',
#  'Bike_GSX-R750 MY18 Road Manual 6sp',
#  'Brand_Ducati',
#  'Side_Stand_Standard',
#  'Bike_899 Panigale Road Manual 899cc',
#  'Registration_Expiry_01/08/2019',
#  'Bike_F4 1000 ABS Road Manual 1000cc',
#  'Bike_S 1000 RR Sport Road Manual 6sp 1000cc',
#  'Warranty_KMs_999999.0',
#  'Registration_Expiry_01/04/2018',
#  'Engine_Config_V-Twin',
#  'Bike_CBR300R ABS MY17 Road Manual',
#  'Model_Gsx r1000 25th anniversary edition',
#  'Seat_Height',
#  'Rear_Suspension_Hydraulic',
#  'Lock_Type_Fork Lock with Key (Steering Stem)',
#  'Brand_Kawasaki',
#  'Swingarm_Type_Dual Sided',
#  'Bike_Ninja ZX-10R ABS 30th Anniversary  Road Manual 6sp 1000cc',
#  'Bike_Road Manual 6sp 1198cc',
#  'Age',
#  'Exhaust_Config_2 into 1',
#  'Model_1199 panigale s tricolore',
#  'Model_Ninja zx 6r 636 abs 30th anniversary zx636fffa',
#  'Bike_848 EVO Corse SE Road Manual 6sp 848cc',
#  'Linked_Braking_System_No',
#  'Bike_Ninja 300 ABS MY16 Road Manual',
#  'Bike_Ninja 300 ABS SE 30th Anniversary MY15 Road Manual 6sp',
#  'Bike_Daytona 675 ABS Road Manual 6sp 675cc',
#  'Exhaust_Config_4 into 2',
#  'Registration_Expiry_01/11/2019',
#  'Model_Ninja 300 se krt replica ex300a',
#  'Model_Cbr1000rra abs fireblade',
#  'Bike_Ninja ZX-10R MY10 Road Manual 6sp',
#  'Bike_GSX250RZ MY18 Road Manual 6sp',
#  'Bike_Ninja ZX-14R ABS Special Edition MY19 Road Manual 6sp',
#  'Model_Hayabusa gsx1300r',
#  'Bike_F3 800 Ago Road Manual 6sp 800cc',
#  'Brand_Bmw',
#  'Bike_YZF-R15 MY15 Road Manual 5sp',
#  'Bike_GSX-R600 MY17 Road Manual 6sp',
#  'Bike_GSX-R1000  GSX-R1000 - 988cc',
#  'Bike_CBR250RA  SE Mugen Road Manual 6sp 250cc',
#  'Bike_Ninja ZX-10R ABS MY16 Road Manual 6sp',
#  'Bike_GSX-R1000 MY08 Road Manual 6sp',
#  'Model_f4 1000',
#  'Bike_CBR300R Road Manual 300cc',
#  'Country_of_Origin_INDIA',
#  'Model_Ninja zx 6r zx600',
#  'Bike_Ninja ZX-10R KRT ABS Replica MY18 Road Manual 6sp',
#  'Bike_Road Manual 6sp 749cc',
#  'Registration_Expiry_01/05/2020',
#  'Bore',
#  'Front_Brake_Caliper(s)_Six Piston',
#  'Bike_GSX-R750 20th Anniversary  Road Manual 750cc',
#  'Registration_Expiry_01/07/2017',
#  'Frame_Material_Steel',
#  'Bike_Ninja ZX-6R MY13 Road Manual 6sp',
#  'Front_Brake_Diameter',
#  'Model_Cbr250ra abs se repsol',
#  'Wheel_Type_Spoke',
#  'Brand_Cagiva',
#  'Bike_Road Manual 6sp 1098cc',
#  'Fuel_Tank_Capacity',
#  'Bike_F3 800 MY19 Road Manual',
#  'Bike_GSX-R600',
#  'Model_996',
#  'Model_f3 800',
#  'Model_Supersport s',
#  'Bike_GT650R EFI Road Manual 6sp 650cc',
#  'Registration_Expiry_01/09/2018',
#  'Wheelbase',
#  'Bike_CBR954RR Fireblade Road Manual 6sp 954cc',
#  'Bike_CBR600RR MY13 Road Manual 6sp',
#  'Bike_Ninja 300 ABS Special Edition MY14 Road Manual',
#  'Bike_YZF-R15 Road Manual 6sp 150cc',
#  'Seating_Position_Relaxed',
#  'Bike_Ninja ZX-14R ABS Special Edition  Road Manual 1400cc   ZX1400FFFA)',
#  'Model_959 panigale',
#  'Frame_Material_Chrome',
#  'Front_Suspension_Upside Down',
#  'Cooling_Liquid & Oil',
#  'Model_Ninja zx 14r abs special edition zx1400fa',
#  'Compression_Ratio',
#  'Colour_gold',
#  'Model_Cbr500r',
#  'Bike_GSX-R600 Road Manual 6sp 600cc',
#  'Bike_TT600 Road Manual 6sp 600cc',
#  'Model_f3 675 eas',
#  'Bike_Ninja ZX-10R ABS MY17 Road Manual 6sp',
#  'Bike_Ninja ZX-6R  Special Edition Road Manual 6sp 636cc',
#  'Ignition_Digital',
#  'Starter_Electric',
#  'Registration_Expiry_01/05/2018',
#  'Rear_Suspension_Shock',
#  'Bike_CBR250R ABS Road Manual 6sp 250cc',
#  'Bike_HP4 Road Manual 1000cc',
#  'Bike_Ninja 300 SE KRT Replica  Road Manual 6sp 300cc',
#  'Model_Yzf r1 anniversary',
#  'Registration_Expiry_01/02/2018',
#  'Bike_1199 Panigale S Road Manual 6sp 1200cc',
#  'Bike_SuperSport S Road Manual 6sp 950cc',
#  'Cam_Type_SOHC (Single Over Head Cam)',
#  'Registration_Expiry_01/12/2019',
#  'Carburettor_Electronic fuel injection',
#  'Bike_620 Sport Lite',
#  'Bike_GSX-R1000 MY16 Road Manual 6sp',
#  'Bike_S 1000 RR Road Manual 6sp 1000cc',
#  'Model_f4 rr 1000',
#  'Model_848 evo',
#  'Bike_SuperSport Road Manual 6sp 937cc',
#  'Bike_996 Strada Road Manual 6sp 996cc',
#  'Bike_RSV1000R Mille Road Manual 6sp 1000cc',
#  'Rear_Brake_Description_Calliper',
#  'Model_S 1000 rr',
#  'Rear_Suspension_Spring',
#  'Colour_yellow',
#  'Bike_S 1000 RR Race Road Manual 6sp 1000cc',
#  'Bike_ZX-7R Ninja  Road Manual 6sp 750cc',
#  'Bike_Ninja ZX-10R 30th Anniversary  Road Manual 6sp 1000cc',
#  'Model_Cbr250ra abs se mugen',
#  'Bike_Daytona 675 ABS MY14 Road Manual 6sp',
#  'Bike_Ninja ZX-10R MY09 Road Manual 6sp',
#  'Bike_CBR500RA MY14 Road Manual',
#  'Bike_MY15 Daytona 675',
#  'Colour_brown',
#  'Country_of_Origin_KOREA',
#  'Warranty_KMs_10000.0',
#  'Model_Ninja zx 10r abs',
#  'Model_Zx6r',
#  'Bike_1198 S Corse Edition',
#  'Bike_RSV4 Factory APRC Road Manual 6sp 1000cc',
#  'Bike_YZF-R3 Road Manual 6sp 300cc',
#  'Model_Cbr1000rr repsol limited edition',
#  'Model_620 sport lite',
#  'Colour_silver',
#  'Model_Rsv4 factory aprc abs',
#  'Traction_Control_Standard',
#  'Bike_VTR1000SP2 Road Manual 6sp 1000cc',
#  'Registration_Expiry_01/03/2019',
#  'Lock_Type_Ignition/Steering',
#  'Registration_Expiry_01/04/2020',
#  'Model_Ninja 250r special edition',
#  'Model_Rsv4 r aprc abs',
#  'Engine_Config_L-Twin',
#  'Carburettor_Constant velocity',
#  'Bike_SB6',
#  'Bike_CBR600RR Telefonica Road Manual 6sp 599cc',
#  'Bike_F4 RR 1000 Road Manual 1000cc',
#  'Model_Cbr300r',
#  'Exhaust_Config_3 into 1',
#  'Bike_S 1000 RR MY16 Road Manual 6sp',
#  'Front_Brake_Description_Calliper',
#  'Carburettor_Digital fuel injection',
#  'Model_Ninja zx 6r zx636',
#  'Bike_Ninja ZX-14R ABS Special Edition  Road Manual 1400cc  ZX1400FEFA)',
#  'Model_848 evo corse se',
#  'Model_Ninja zx 6rr zx600',
#  'Model_Ninja zx 6r abs 636',
#  'Cam_Type_DOHC (Double Over Head Cam)',
#  'Model_Ninja 300 abs ex300b',
#  'Bike_GSX-R1000 MY12 Road Manual 6sp',
#  'Bike_Daytona 675 MY13 Road Manual 6sp',
#  'Ignition_Electronic',
#  'Bike_959 Panigale MY19 Road Manual 6sp',
#  'Engine_Config_Inline',
#  'Registration_Expiry_01/07/2019',
#  'Model_916',
#  'Cooling_Liquid',
#  'Sold_Sold',
#  'Bike_F4 1000S Corse',
#  'Bike_Motrac  Road Manual 250cc',
#  'Bike_MY04 Road Manual 6sp',
#  'Model_f4 1000 abs',
#  'Clutch_Type_Anti-hop',
#  'Bike_F3 800 Road Manual 800cc',
#  'Bike_RSV1000 Mille Road Manual 6sp 1000cc',
#  'Model_Cbr600rr',
#  'Bike_Ninja 250R MY10 Road Manual 6sp',
#  'Bike_Ninja 300 Special Edition MY13 Road Manual',
#  'Model_Rsv1000 mille',
#  'Model_f4 312 r 1000 11',
#  'Country_of_Origin_CHINA',
#  'Bike_Daytona 675 R Road Manual 6sp 675cc',
#  'Bike_ZXR750  Road Manual 6sp 750cc',
#  'Bike_DB8 Road Manual 6sp 1198cc',
#  'Bike_1199 Panigale Road Manual 6sp',
#  'Model_749s biposto',
#  'ABS_No',
#  'Bike_Ninja 300 ABS Special Edition Road Manual 300cc',
#  'Bike_CBR900RR Fireblade',
#  'Bike_GSX-R750 Special Edition  Road Manual 750cc',
#  'Model_f4 r',
#  'Model_Cbr900rr fireblade 929',
#  'Model_Ninja zx 6r zx600r',
#  'Rear_Brake_Caliper(s)_Four Piston',
#  'Bike_Ninja 400 KRT Edition MY19 Road Manual 6sp',
#  'Bike_1098 S MY08 Road Manual 6sp',
#  'Front_Suspension_Hydraulic',
#  'Model_Cbr250r se mugen',
#  'Bike_YZF-R1 MY17 Road Manual 6sp',
#  'Bike_F4 1000 Road Manual 1000cc',
#  'Bike_YZF-R1M MY19 Road Manual 6sp',
#  'Model_Yzf r3',
#  'Bike_Hayabusa MY18 Road Manual 6sp',
#  'Bike_F3 675 EAS MY19 Road Manual',
#  'Model_Gsx r1000 988cc',
#  'Model_f3 800 ago',
#  'Rear_Brake_Description_Hydraulic',
#  'Bike_F4 312 R 1000 1+1',
#  'Bike_959 Panigale Corse MY19 Road Manual 6sp',
#  'Bike_Ninja ZX-6R ABS  Road Manual 600cc',
#  'Bike_HP4 Competition MY13 Road Manual',
#  'Registration_Expiry_01/12/2020',
#  'Registration_Expiry_01/03/2020',
#  'Bike_Ninja 250R MY12 Road Manual 6sp',
#  'Model_Ninja zx 6r abs 636 krt replica zx636f',
#  'Clutch_Type_Other',
#  'Bike_S 1000 RR MY18 Road Manual 6sp',
#  'Seating_Position_Upright',
#  'Model_Gsx r1000 abs',
#  'Registration_Expiry_01/11/2018',
#  'Model_Mito 125',
#  'Bike_Ninja 300 ABS Special Edition MY13 Road Manual',
#  'Engine_Config_Parallel',
#  'Model_996 strada',
#  'Bike_YZF-R6SP Road Manual 6sp 600cc',
#  'Clutch_Type_Hydraulically operated',
#  'Bike_Ninja 250R Special Edition MY12 Road Manual 6sp',
#  'Bike_MY14 Daytona 675',
#  'Bike_CBR600RR Road Manual 6sp 599cc',
#  'Model_Cbr600f4i',
#  'Model_Panigale v4',
#  'Model_1098s tri colore',
#  'Bike_YZF-R15 MY13 Road Manual 5sp',
#  'Bike_749s Biposto Road Manual 6sp 749cc',
#  'Model_f3 675',
#  'Bike_Ninja ZX-6R  Road Manual 6sp 600cc',
#  'Bike_Road Manual 6sp 999cc',
#  'Model_Yzf r1m',
#  'Bike_CBR300R ABS MY15 Road Manual',
#  'ABS_Standard',
#  'Model_Gsx r750 20th anniversary gsx r750x',
#  'Model_959 panigale corse',
#  'Model_Ninja 250r ex250j',
#  'Bike_Ninja ZX-6R  Road Manual 6sp 636cc',
#  'Bike_GSX-R1000 Road Manual 6sp 1000cc',
#  'Registration_Expiry_01/01/2018',
#  'Model_Yzf r1sp',
#  'Model_Ninja zx 10r abs se zx1000kf',
#  'Registration_Expiry_01/06/2019',
#  'Bike_Daytona 675 SE Road Manual 6sp 675cc',
#  'Model_Gsx r750 special edition gsx r750z',
#  'Bike_YZF-R1 MY16 Road Manual 6sp',
#  'Engine_Config_V4',
#  'Model_Ninja 300 special edition',
#  'Cam_Type_Reed Valve',
#  'Model_Db7',
#  'Model_Ninja zx 10r krt replica zx1000r',
#  'Clutch_Type_Slipper',
#  'Bike_Ninja 300 ABS Special Edition MY15 Road Manual',
#  'Swingarm_Type_Single Sided',
#  'Brand_Triumph',
#  'Model_Cbr300r abs cbr300ra',
#  'Bike_CBR1000RRA ABS Fireblade MY17 Road Manual 6sp',
#  'Bike_CBR250R SE Repsol MY13 Road Manual',
#  'Model_Ninja zx 6r zx636 special edition',
#  'Bike_Ninja ZX-10R Road Manual 6sp 1000cc',
#  'Country_of_Origin_THAILAND',
#  'Bike_Road Manual 6sp 996cc',
#  'Live_Add',
#  'Bike_GSX250RZ Road Manual 6sp 250cc',
#  'Model_Daytona 675 abs',
#  'Model_Rsv4 factory aprc',
#  'Bike_GSX-R750 Road Manual 6sp 750cc',
#  'Registration_Expiry_01/06/2020',
#  'Bike_F3 800 RC Road Manual 6sp 800cc',
#  'Bike_Ninja ZX-10RR  Road Manual 6sp 1000cc',
#  'Side_Stand_Yes',
#  'Rear_Brake_Description_Disc',
#  'Seller_Private',
#  'Registration_Expiry_01/01/1970',
#  'Bike_GT650R EFI MY15 Road Manual 6sp',
#  'Bike_F4 750 S Road Manual 6sp 750cc',
#  'Bike_Ninja ZX-10R ABS MY12 Road Manual 6sp',
#  'Country_of_Origin_INDONESIA',
#  'Model_Ninja 400 special edition ex400g',
#  'Bike_ZX-12R Road Manual 6sp 1200cc',
#  'Bike_1199 Panigale R ABS Road Manual 1198cc',
#  'Bike_GSX-R1000 MY10 Road Manual 6sp',
#  'Bike_CBR300R ABS SE MY15 Road Manual 6sp',
#  'Bike_YZF-R15 MY16 Road Manual 6sp',
#  'Bike_GSX250R Road Manual 6sp 250cc',
#  'Front_Suspension_Telescopic',
#  'Model_Yzf r6',
#  'Bike_999S MY04 Road Manual 6sp',
#  'Bike_F3 675 EAS Road Manual 675cc',
#  'Induction_System_Supercharged',
#  'Bike_GSX-R1000 MY13 Road Manual 6sp',
#  'Bike_S 1000 RR Race MY19 Road Manual 6sp',
#  'Model_Ninja zx 14r abs special edition zx1400j',
#  'Bike_MY13 Daytona 675',
#  'Model_999s biposto',
#  'Model_f4 750 s',
#  'Ignition_CDI (Capacitive Discharge Ignition)',
#  'Bike_Ninja ZX-6R ABS  KRT Replica  Road Manual 6sp 636cc',
#  'Height',
#  'Length',
#  'Trail',
#  'Model_848',
#  'Model_Ninja zx 10r abs 30th anniversary zx1000k',
#  'Bike_Ninja ZX-10R ABS SE  Road Manual 1000cc',
#  'Model_Ninja zx 6r 636',
#  'Bike_CBR650R ABS MY19 Road Manual 6sp',
#  'Model_Ninja 400 krt edition ex400g',
#  'Bike_YZF-R1 MY19 Road Manual 6sp',
#  'Bike_Ninja ZX-10R KRT ABS Replica Road Manual 6sp 1000cc',
#  'Bike_Ninja 300 ABS MY13 Road Manual',
#  'Model_1199 panigale r abs',
#  'Model_f4 312 r 1000',
#  'Colour_white',
#  'Bike_Ninja ZX-10R KRT ABS Replica MY16 Road Manual 6sp',
#  'Bike_CBR250RA SE Repsol MY13 Road Manual',
#  'Front_Brake_Caliper(s)_Double Piston',
#  'Model_Rsv1000r mille',
#  'Bike_CBR250R Road Manual 6sp 250cc',
#  'Model_Rsv4 r aprc',
#  'Model_Gt650r efi',
#  'Bike_Hayabusa MY15 Road Manual 6sp',
#  'Country_of_Origin_GERMANY',
#  'Bike_YZF-R1SP MY16 Road Manual 6sp',
#  'Bike_CBR954RR Fireblade',
#  'Traction_Control_No',
#  'Bike_Daytona 675 MY12 Road Manual 6sp',
#  'Bike_GSX-R750 MY15 Road Manual 6sp',
#  'Bike_YZF-R6 MY18 Road Manual 6sp',
#  'Bike_GSX-R1000 ABS Road Manual 6sp 999cc',
#  'Model_Gsx r1000r',
#  'Colour_grey',
#  'Bike_GSX-R1000 ABS MY17 Road Manual 6sp',
#  'Bike_CBR600F4i Road Manual 6sp 600cc',
#  'Colour_blue',
#  'Front_Suspension_Inverted',
#  'Model_Vtr1000sp 2',
#  'Bike_Ninja ZX-10R ABS KRT Winter Edition  Road Manual 6sp 998cc',
#  'Model_Hp4 competition',
#  'Model_Daytona 675',
#  'Bike_CBR600RRA',
#  'Bike_RSV4 Factory APRC ABS Road Manual 6sp 1000cc',
#  'Cooling_Forced Air',
#  'Model_Cbr250r se repsol',
#  'Model_Gsx r750',
#  'Bike_RS4 125  Road Manual 6sp 125cc',
#  'Bike_CBR1000RR FireBlade Road Manual 6sp 1000cc',
#  'Engine_Config_Unknown',
#  'Bike_CBR500R Road Manual 500cc',
#  'Cylinders',
#  'Country_of_Origin_JAPAN',
#  'Model_899 panigale',
#  'Front_Suspension_Spring',
#  'Registration_Expiry_01/07/2020',
#  'Model_Ninja h2 zx1000n',
#  'Bike_Ninja ZX-10R Special  Road Manual 6sp 1000cc',
#  'Model_Zxr750 zx750',
#  'Model_1098',
#  'Bike_Ninja ZX-6R MY10 Road Manual 6sp',
#  'Bike_Daytona 675 R',
#  'Bike_F4 312 R 1000',
#  'Model_1198',
#  'Bike_CBR250RA  SE Repsol Road Manual 250cc',
#  'Bike_CBR300R ABS  Road Manual 300cc',
#  'Model_Cbr500ra abs',
#  'Model_Gsx250rz',
#  'Learner_Approved_Yes',
#  'Model_1098 s',
#  'Bike_Ninja ZX-6R MY12 Road Manual 6sp',
#  'Model_998',
#  'Model_Ninja 300 abs se 30th anniversary',
#  'Model_Cbr954rr fireblade',
#  'Frame_Material_Aluminium',
#  'Model_Ninja zx 6r monster energy zx600r',
#  'Model_S 1000 rr race',
#  'Bike_Hayabusa MY12 Road Manual 6sp',
#  'Engine_Config_Vertical',
#  'Bike_F4 750 S  F4-750S',
#  'Induction_System_Aspirated',
#  'Bike_848 EVO MY11 Road Manual 6sp',
#  'Front_Suspension_Conventional Fork',
#  'Model_999s',
#  'Registration_Expiry_01/07/2018',
#  'Colour_orange',
#  'Brand_MV Agusta',
#  'Registration_Expiry_01/02/2019',
#  'Bike_F4AGO 1000 Road Manual 6sp 1000cc',
#  'Bike_GSX-R1000 MY11 Road Manual 6sp',
#  'Bike_1098 S Road Manual 6sp 1098cc',
#  'Bike_Ninja ZX-6R Monster Energy  Road Manual 600c',
#  'Bike_Ninja ZX-14R ABS MY13 Road Manual',
#  'Stroke',
#  'Bike_Ninja 250R  Road Manual 6sp 250cc',
#  'Bike_RSV4 R APRC Road Manual 6sp 1000cc',
#  'Model_Cbr300r abs se cbr300rase',
#  'Bike_CBR600RR MY12 Road Manual 6sp',
#  'Bike_Daytona 675 ABS MY15 Road Manual 6sp',
#  'Bike_Hayabusa MY13 Road Manual 6sp',
#  'Registration_Expiry_01/04/2017',
#  'Model_1198 s',
#  'Engine_Type_Piston',
#  'Bike_Ninja ZX-10R ABS Road Manual 6sp 1000cc',
#  'Carburettor_Fuel injection',
#  'Bike_CBR500RA  Road Manual 500cc',
#  'Bike_899 Panigale MY15 Road Manual',
#  'Seller_Dealer',
#  'Bike_CBR300R ABS SE  Road Manual 6sp 300cc',
#  'Bike_YZF-R3 MY18 Road Manual 6sp',
#  'Warranty_in_Months_from_First_Registration',
#  'Bike_CBR500RA MY17 Road Manual',
#  'Bike_CBR600RR MY17 Road Manual 6sp',
#  'Bike_Ninja 300 ABS Special Edition MY16 Road Manual',
#  'Brand_Yamaha',
#  'Bike_848 EVO Road Manual 6sp 849cc',
#  'Bike_Ninja 400 MY19 Road Manual 6sp',
#  'Front_Brake_Caliper(s)_Single Piston',
#  'Model_999',
#  'Model_Gsx r1000 limited edition motogp',
#  'Colour_red',
#  'Linked_Braking_System_Part-Integral',
#  'Model_Ninja zx 10r special zx1000d',
#  'Model_Ninja 300 abs special edition',
#  'Bike_Road Manual 6sp 916cc',
#  'Bike_MY09',
#  'Bike_MY09 Road Manual 6sp',
#  'Model_Sb6',
#  'Model_Zx 7r ninja zx750',
#  'Model_Gsx r600',
#  'Bike_Ninja 250R MY11 Road Manual 6sp',
#  'Model_Yzf r15',
#  'Seating_Position_Forward',
#  'Bike_CBR1000RR Repsol Road Manual 1000cc',
#  'Model_Cbr600rr hannspree ten kate',
#  'Registration_Expiry_01/01/2012',
#  'Bike_YZF-R6 MY13 Road Manual 6sp',
#  'Bike_999S Road Manual 6sp 999cc',
#  'Model_Db8',
#  'Bike_CBR1000RR FireBlade MY07 Road Manual 6sp',
#  'Ignition_CD (Capacitor Discharge)',
#  'Bike_F3 675 Road 675cc',
#  'Bike_Ninja 300 ABS  Road Manual 300cc',
#  'Front_Brake_Description_Disc',
#  'Model_1198 s corse edition',
#  'Bike_Ninja 250R Special Edition MY10 Road Manual 6sp',
#  'Bike_CBR650F LAMS  Road Manual 6sp 650cc',
#  'Dry_Weight',
#  'Bike_Hayabusa MY16 Road Manual 6sp',
#  'Colour_green',
#  'Width',
#  'Model_f4 1000s corse',
#  'Model_f4 rr',
#  'Charging_Method_Alternator & Regulator-Rectifier',
#  'Learner_Approved_No',
#  'Cam_Type_Desmodromic',
#  'Front_Brake_Caliper(s)_Four Piston',
#  'Model_Ninja zx 14r abs zx1400',
#  'Bike_YZF-R6 MY16 Road Manual 6sp',
#  'Bike_GSX-R1000 30th Anniversary Edition Road Manual 6sp 1000cc',
#  'Model_Cbr650f lams cbr650fl',
#  'Bike_Ninja ZX-10R ABS 30th Anniversary MY15 Road Manual 6sp',
#  'Registration_Expiry_01/05/2019',
#  'Model_Daytona 675 se',
#  'Bike_S 1000 RR MY19 Road Manual 6sp',
#  'Colour_black',
#  'Registration_Expiry_01/06/2018',
#  'Bike_Mito 125',
#  'Registration_Expiry_01/10/2019',
#  'Ignition_Digital Electronic',
#  'Registration_Expiry_01/11/2020',
#  'Bike_F4 R Road Manual 1000cc',
#  'Model_Cbr600rra abs',
#  'Model_Rs4 125 4t',
#  'Bike_DB7 Road Manual 6sp 1100cc',
#  'Model_1199 panigale s',
#  'Rear_Brake_Caliper(s)_Double Piston',
#  'Bike_Ninja 300 ABS MY14 Road Manual',
#  'Model_Hp4',
#  'Bike_Daytona 675 Road Manual 6sp 675cc',
#  'Model_f3 800 rc',
#  'Model_749',
#  'Bike_CBR500R MY14 Road Manual',
#  'Bike_Hayabusa MY14 Road Manual 6sp',
#  'Bike_CBR600RR MY09 Road Manual 6sp',
#  'Bike_ZX6R',
#  'Model_Ninja zx 14',
#  'Brand_Hyosung',
#  'Ground_Clearance',
#  'Bike_Hayabusa MY17 Road Manual 6sp',
#  'Bike_MY08 Road Manual 6sp',
#  'Engine_Size',
#  'Rear_Suspension_Travel',
#  'Rear_Brake_Caliper(s)_Single Piston',
#  'Bike_800 Sport half fairing Road Manual 6sp 800cc',
#  'Model_Yzf r1',
#  'Bike_GT650R EFI MY13 Road Manual 6sp',
#  'Bike_CBR250R SE Repsol Road Manual 250cc',
#  'Registration_Expiry_01/09/2019',
#  'Model_Ninja zx 10r 30th anniversary zx1000jf',
#  'Bike_S 1000 RR M Sport MY19 Road Manual 6sp',
#  'Model_Cbr650r abs',
#  'Country_of_Origin_ITALY',
#  'Bike_Ninja 300 Special Edition Road Manual 300cc',
#  'Bike_YZF-R15 MY15 Road Manual 6sp']

# %%
#sport_df = sport.df
#sport_df.drop(['Predicted_Price','Price_ratio','Deal_type'],axis=1, inplace=True)
def adjusted_r2(r2, n, k):
        return 1 - (1-r2)*((n-1)/(n-k-1)) 

    
target = 'Price'
feature_set = list(set(sport_df.select_dtypes(include='number').columns) - set([target]))

model = RidgeCV(cv=5)

X = sport_df[feature_set]
y = sport_df[target]

X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=1, test_size=0.3)

n = X_train.shape[0]

best_score = 0
best_feature = ''
included = []

# top 10 features
while True:
    changed = False

    for col in feature_set:
        
        model.fit(X_train[included + [col]], y_train)
        r2 = model.score(X_test[included + [col]], y_test)

        k = len(included + [col]) + 1
        score = adjusted_r2(r2,n,k) 

        if (score > best_score):
            best_score = score
            best_feature = col
            changed = True
            

    if changed:
        included.append(best_feature)
        print (f'ADDED: {best_feature}; score: {best_score:.3f}')
        # reset for the next round
        #best_score = 0
        #best_feature = ''
        feature_set = list(set(feature_set) - set(included))
        
    else:
        break
    
    
    
    
print (included)
# Out:
# ADDED: Traction_Control_Standard; score: 0.517
# ADDED: Engine_Size; score: 0.703

# %%
feature_set

#len(included)

# %%
model = RidgeCV(cv=5)
model.fit(X_train[included], y_train)
model.score(X_test[included], y_test)
# Out:
# 0.9070676541117689

# %%
model.fit(sport_df[included],sport_df[target])
predictions = model.predict(sport_df[included])
sport_df['Predicted_Price'] = predictions

# %%
sport_df['Price_ratio'] = sport_df['Price'] / sport_df['Predicted_Price']

sport_df['Deal_type'] = 'Dont Bother *'
sport_df['Deal_type'][sport_df['Price_ratio'] < 0.9] = 'Negotiate **'
sport_df['Deal_type'][sport_df['Price_ratio'] < 0.8] = 'Good Deal ***'
sport_df['Deal_type'][sport_df['Price_ratio'] < 0.75] = 'Great Deal ****'        
sport_df['Deal_type'][sport_df['Price_ratio'] < 0.5] = 'Its a steal *****'

# %%
def scatter(data,x,y,hue=None,title='',figsize=(12,10)):
    ax = plt.figure(figsize=figsize)
    sns.scatterplot(x=x,y=y,hue=hue,data=data);
    plt.title(title,fontsize=14)
    plt.legend(bbox_to_anchor=(1.05, 1), loc=2, borderaxespad=0.)
    #plt.ylim(0,40000)

scatter(sport_df,'Price','Predicted_Price',hue='Deal_type',title='Great Deals on Motorbikes')

# %%
sport.df.columns
# Out:
# Index(['Bore', 'Carburettor(s)', 'Compression_Ratio', 'Cylinders',
#        'Dry_Weight', 'Engine_Description', 'Front_Brake_Diameter',
#        'Front_Suspension_Travel', 'Fuel_Reserve_Capacity',
#        'Fuel_Tank_Capacity',
#        ...
#        'Model_f4 1000 abs', 'Model_f4 1000s corse', 'Model_f4 312 r 1000',
#        'Model_f4 312 r 1000 11', 'Model_f4 750 s', 'Model_f4 750 s f4s 11',
#        'Model_f4 r', 'Model_f4 rr', 'Model_f4 rr 1000', 'Model_f4ago 1000'],
#       dtype='object', length=1647)

# %%
bike_cols = [col for col in sport.df.columns if 'Bike' in col]
brand_cols = [col for col in sport.df.columns if 'Brand' in col]
model_cols = [col for col in sport.df.columns if 'Model' in col]
niave_feature = ['Kilometers','Age']


features = [niave_feature, bike_cols, brand_cols, model_cols]

for i, col in enumerate(features):
    
    sport.model = sport.find_best_model(col, sport.df['Price'])
    
    sport.fit(sport.df[niave_feature],sport.df['Price'])
    
    predictions = sport.predict(sport.df[niave_feature])
    sport.df['Predicted_Price_'+str(i)] = predictions

# %%
pred_cols = [col for col in sport.df.columns if 'Predicted' in col]
sport.df[pred_cols].head()
# Out:
#    Predicted_Price  Predicted_Price_0  Predicted_Price_1  Predicted_Price_2  \
# 0      5766.422408        5766.422408        5766.422408        5317.638077
# 1      9793.277150        9793.277150        9793.277150        9997.887675
# 2      4239.099500        4239.099500        4239.099500        3502.268535
# 3      5903.430252        5903.430252        5903.430252        4923.078853
# 4      7352.072148        7352.072148        7352.072148        6921.687257
#
#    Predicted_Price_3
# 0        5766.422408
# 1        9793.277150
# 2        4239.099500
# 3        5903.430252
# 4        7352.072148

# %%
sport_df[['Price','Predicted_Price','Price_ratio','Deal_type']][sport_df['Price'] > 15000].head(10)
# Out:
#         Price  Predicted_Price  Price_ratio    Deal_type
# 1127  15200.0     15942.485560     0.953427  Dont Bother
# 1128  15200.0     14838.217986     1.024382  Dont Bother
# 1129  15500.0     16299.801669     0.950932  Dont Bother
# 1130  15500.0     15537.357269     0.997596  Dont Bother
# 1131  15500.0     15509.065737     0.999415  Dont Bother
# 1132  15500.0     15844.266557     0.978272  Dont Bother
# 1133  15500.0     11012.781500     1.407456    Good Deal
# 1134  15500.0     11697.645542     1.325053    Good Deal
# 1135  15600.0     17851.471749     0.873878  Dont Bother
# 1136  15700.0     16723.216950     0.938815  Dont Bother
